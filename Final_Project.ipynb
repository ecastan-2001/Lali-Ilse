# %% [markdown]
# ##Milestone 1 - Ilse & Lali
#
# Goals:
#  - Tell a story about data
#  - Find the difference of exports and imports during a 10 year period in Luxembourg and look at any patterns, trends, and changes in trade flows over time.
#  - Look at the data and see if countries have been getting more specialized in their exports and imports during time.
#  - Compare the data from Luxembourg to other countries
#  - Create a dashboard using Manganite
#
# Milestone 1:
# - Clean Luxembourg data
# - Create graphs for Luxembourg imports and exports
#
# Milestone 2:
# - Clean data for Germany, Belgium, France and Netherlands
# - Compare Luxembourg's exports and imports against the mentioned countries for all categories during the 10 year period.
# - Choose one specific category to focus and make a detailed comparison.

# %%
import pandas as pd
import polars as pl
import plotly.express as px
import csv
import plotly.io as pio
pio.templates.default = 'plotly_white'
import matplotlib.pyplot as plt
import numpy as np
import plotly.graph_objects as go

# %% [markdown]
# # What did Luxembourg export between 2010 and 2020

# %%
url = "https://www.dl.dropboxusercontent.com/scl/fi/vkwffpdw6rvlxug3einxc/Luxembourg-export-between-2010-and-2020.csv?rlkey=2jfcgis7vbovlkr9srxzkm5cj&dl=1"

df_1 = pd.read_csv(url)

df_1 = df_1.drop('Code', axis=1)
df_1 = df_1.rename(columns={'Current Gross Export': 'Gross Export in USD'})
df_1['Gross Export in USD'] = df_1['Gross Export in USD'].str.replace("$", "")
df_1['Gross Export in USD'] = df_1['Gross Export in USD'].str.replace('M', 'e6').str.replace('B', 'e9')
df_1['Gross Export in USD'] = pd.to_numeric(df_1['Gross Export in USD'], errors='coerce').astype('Int64')


display(df_1)
# Out:
# <ipython-input-2-61652691bd6b>:7: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_1['Gross Export in USD'] = df_1['Gross Export in USD'].str.replace("$", "")
#                                            Name  Year  Gross Export in USD  \
# 0    Textiles, garments, footwear and furniture  2010            693000000
# 1    Textiles, garments, footwear and furniture  2011            818000000
# 2    Textiles, garments, footwear and furniture  2012            707000000
# 3    Textiles, garments, footwear and furniture  2013            680000000
# 4    Textiles, garments, footwear and furniture  2014            691000000
# ..                                          ...   ...                  ...
# 116                                    Services  2016          94100000000
# 117                                    Services  2017         101000000000
# 118                                    Services  2018         109000000000
# 119                                    Services  2019         113000000000
# 120                                    Services  2020         121000000000
#
#        Sector
# 0    Textiles
# 1    Textiles
# 2    Textiles
# 3    Textiles
# 4    Textiles
# ..        ...
# 116  Services
# 117  Services
# 118  Services
# 119  Services
# 120  Services
#
# [121 rows x 4 columns]

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121 entries, 0 to 120
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 121 non-null    object
#  1   Year                 121 non-null    int64
#  2   Gross Export in USD  121 non-null    Int64
#  3   Sector               121 non-null    object
# dtypes: Int64(1), int64(1), object(2)
# memory usage: 4.0+ KB

# %%
df_1 = df_1.sort_values(by="Year")
df_1
# Out:
#                                            Name  Year  Gross Export in USD  \
# 0    Textiles, garments, footwear and furniture  2010            693000000
# 99                                        Other  2010            573000000
# 44                                       Metals  2010           5140000000
# 77                    Machinery and instruments  2010           2370000000
# 22                    Stone, glass and ceramics  2010            420000000
# ..                                          ...   ...                  ...
# 65                       Chemicals and plastics  2020           3050000000
# 87                    Machinery and instruments  2020           1970000000
# 32                    Stone, glass and ceramics  2020            411000000
# 43              Minerals, fuels, ores and salts  2020            136000000
# 120                                    Services  2020         121000000000
#
#         Sector
# 0     Textiles
# 99       Other
# 44      Metals
# 77   Machinery
# 22       Stone
# ..         ...
# 65   Chemicals
# 87   Machinery
# 32       Stone
# 43    Minerals
# 120   Services
#
# [121 rows x 4 columns]

# %%
fig = px.line(df_1, x="Year", y="Gross Export in USD", color="Sector")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="be7f5414-0818-45f5-9257-4fc21c734336" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("be7f5414-0818-45f5-9257-4fc21c734336")) {                    Plotly.newPlot(                        "be7f5414-0818-45f5-9257-4fc21c734336",                        [{"hovertemplate":"Sector=Textiles\u003cbr\u003eYear=%{x}\u003cbr\u003eGross Export in USD=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Textiles","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Textiles","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[693000000,818000000,707000000,680000000,691000000,643000000,643000000,608000000,656000000,784000000,817000000],"yaxis":"y","type":"scatter"},{"hovertemplate":"Sector=Other\u003cbr\u003eYear=%{x}\u003cbr\u003eGross Export in USD=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Other","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Other","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[573000000,677000000,856000000,785000000,909000000,731000000,892000000,820000000,915000000,394000000,393000000],"yaxis":"y","type":"scatter"},{"hovertemplate":"Sector=Metals\u003cbr\u003eYear=%{x}\u003cbr\u003eGross Export in USD=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Metals","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Metals","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[5140000000,5970000000,4710000000,4710000000,4950000000,4020000000,3800000000,4110000000,4730000000,4140000000,3610000000],"yaxis":"y","type":"scatter"},{"hovertemplate":"Sector=Machinery\u003cbr\u003eYear=%{x}\u003cbr\u003eGross Export in USD=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Machinery","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Machinery","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[2370000000,2150000000,2290000000,2430000000,2610000000,2160000000,2110000000,1990000000,2010000000,2230000000,1970000000],"yaxis":"y","type":"scatter"},{"hovertemplate":"Sector=Stone\u003cbr\u003eYear=%{x}\u003cbr\u003eGross Export in USD=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Stone","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Stone","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[420000000,730000000,489000000,628000000,952000000,546000000,548000000,724000000,541000000,527000000,411000000],"yaxis":"y","type":"scatter"},{"hovertemplate":"Sector=Services\u003cbr\u003eYear=%{x}\u003cbr\u003eGross Export in USD=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Services","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Services","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[62800000000,71500000000,76300000000,87300000000,97800000000,93500000000,94100000000,101000000000,109000000000,113000000000,121000000000],"yaxis":"y","type":"scatter"},{"hovertemplate":"Sector=Agriculture\u003cbr\u003eYear=%{x}\u003cbr\u003eGross Export in USD=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Agriculture","line":{"color":"#FF6692","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Agriculture","orientation":" ...

# %% [markdown]
# #What did Luxembourg import between 2010 and 2020

# %%
url = "https://www.dropbox.com/scl/fi/9dzw3h28263fjirgr7fyj/What-did-Luxembourg-import-between-2010-and-2020_.csv?rlkey=xui2dv36smy3jnh7kaklsqupp&dl=1"

df_2 = (pd.read_csv(url)
        .drop('Code', axis=1)
        .rename(columns={'Current Gross Import': 'Gross Import in USD'})
        .assign(**{'Gross Import in USD': lambda x: x['Gross Import in USD'].str.replace("$", "")
        .str.replace('M', 'e6')
        .str.replace('B', 'e9')})
        .assign(**{'Gross Import in USD': lambda x: pd.to_numeric(x['Gross Import in USD'], errors='coerce').astype('Int64')})
       )

display(df_2)
# Out:
# <ipython-input-6-afb525914551>:6: FutureWarning:
#
# The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#                                            Name  Year  Gross Import in USD  \
# 0    Textiles, garments, footwear and furniture  2010           1430000000
# 1    Textiles, garments, footwear and furniture  2011           1600000000
# 2    Textiles, garments, footwear and furniture  2012           1390000000
# 3    Textiles, garments, footwear and furniture  2013           1430000000
# 4    Textiles, garments, footwear and furniture  2014           1510000000
# ..                                          ...   ...                  ...
# 116                                    Services  2016          69000000000
# 117                                    Services  2017          77600000000
# 118                                    Services  2018          87000000000
# 119                                    Services  2019          91500000000
# 120                                    Services  2020          98300000000
#
#        Sector
# 0    Textiles
# 1    Textiles
# 2    Textiles
# 3    Textiles
# 4    Textiles
# ..        ...
# 116  Services
# 117  Services
# 118  Services
# 119  Services
# 120  Services
#
# [121 rows x 4 columns]

# %%
fig = px.line(df_2, x="Year", y="Gross Import in USD", color="Sector")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="be0d5a9e-b86c-4d90-9ed7-5fd70f4a40e8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("be0d5a9e-b86c-4d90-9ed7-5fd70f4a40e8")) {                    Plotly.newPlot(                        "be0d5a9e-b86c-4d90-9ed7-5fd70f4a40e8",                        [{"hovertemplate":"Sector=Textiles\u003cbr\u003eYear=%{x}\u003cbr\u003eGross Import in USD=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Textiles","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Textiles","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[1430000000,1600000000,1390000000,1430000000,1510000000,1270000000,1330000000,1420000000,1510000000,1550000000,1430000000],"yaxis":"y","type":"scatter"},{"hovertemplate":"Sector=Agriculture\u003cbr\u003eYear=%{x}\u003cbr\u003eGross Import in USD=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Agriculture","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Agriculture","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[3320000000,3630000000,3400000000,3520000000,3750000000,3120000000,3150000000,3300000000,3740000000,3450000000,3540000000],"yaxis":"y","type":"scatter"},{"hovertemplate":"Sector=Stone\u003cbr\u003eYear=%{x}\u003cbr\u003eGross Import in USD=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Stone","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Stone","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[771000000,1060000000,910000000,851000000,626000000,560000000,698000000,694000000,536000000,510000000,544000000],"yaxis":"y","type":"scatter"},{"hovertemplate":"Sector=Minerals\u003cbr\u003eYear=%{x}\u003cbr\u003eGross Import in USD=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Minerals","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Minerals","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[3080000000,4080000000,3730000000,3850000000,3130000000,1980000000,1620000000,1790000000,2700000000,2470000000,1530000000],"yaxis":"y","type":"scatter"},{"hovertemplate":"Sector=Metals\u003cbr\u003eYear=%{x}\u003cbr\u003eGross Import in USD=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Metals","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Metals","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[3390000000,4040000000,3450000000,3490000000,3600000000,2440000000,2340000000,2790000000,3260000000,2750000000,2500000000],"yaxis":"y","type":"scatter"},{"hovertemplate":"Sector=Chemicals\u003cbr\u003eYear=%{x}\u003cbr\u003eGross Import in USD=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Chemicals","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Chemicals","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[3410000000,4250000000,3670000000,3790000000,3560000000,2930000000,2990000000,3480000000,3960000000,3690000000,3460000000],"yaxis":"y","type":"scatter"},{"hovertemplate":"Sector=Vehicles\u003cbr\u003eYear=%{x}\u003cbr\u003eGross Import in USD=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Vehicles","line":{"color":"#FF6692","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Vehicles ...

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121 entries, 0 to 120
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 121 non-null    object
#  1   Year                 121 non-null    int64
#  2   Gross Import in USD  121 non-null    Int64
#  3   Sector               121 non-null    object
# dtypes: Int64(1), int64(1), object(2)
# memory usage: 4.0+ KB

# %%
df_2 = df_2.sort_values(by="Year")
df_2
# Out:
#                                            Name  Year  Gross Import in USD  \
# 0    Textiles, garments, footwear and furniture  2010           1430000000
# 99                                        Other  2010           2240000000
# 44                                       Metals  2010           3390000000
# 77                    Machinery and instruments  2010           3450000000
# 22                    Stone, glass and ceramics  2010            771000000
# ..                                          ...   ...                  ...
# 65                       Chemicals and plastics  2020           3460000000
# 87                    Machinery and instruments  2020           3210000000
# 32                    Stone, glass and ceramics  2020            544000000
# 43              Minerals, fuels, ores and salts  2020           1530000000
# 120                                    Services  2020          98300000000
#
#         Sector
# 0     Textiles
# 99       Other
# 44      Metals
# 77   Machinery
# 22       Stone
# ..         ...
# 65   Chemicals
# 87   Machinery
# 32       Stone
# 43    Minerals
# 120   Services
#
# [121 rows x 4 columns]

# %% [markdown]
# #Add Exports and Imports in just one table

# %%
Gross_Import = df_2['Gross Import in USD']
df_1['Gross Import in USD'] = Gross_Import

df_1
# Out:
#                                            Name  Year  Gross Export in USD  \
# 0    Textiles, garments, footwear and furniture  2010            693000000
# 99                                        Other  2010            573000000
# 44                                       Metals  2010           5140000000
# 77                    Machinery and instruments  2010           2370000000
# 22                    Stone, glass and ceramics  2010            420000000
# ..                                          ...   ...                  ...
# 65                       Chemicals and plastics  2020           3050000000
# 87                    Machinery and instruments  2020           1970000000
# 32                    Stone, glass and ceramics  2020            411000000
# 43              Minerals, fuels, ores and salts  2020            136000000
# 120                                    Services  2020         121000000000
#
#         Sector  Gross Import in USD
# 0     Textiles           1430000000
# 99       Other           2240000000
# 44      Metals           3390000000
# 77   Machinery           3450000000
# 22       Stone            771000000
# ..         ...                  ...
# 65   Chemicals           3460000000
# 87   Machinery           3210000000
# 32       Stone            544000000
# 43    Minerals           1530000000
# 120   Services          98300000000
#
# [121 rows x 5 columns]

# %%
df_1.describe()
# Out:
#               Year  Gross Export in USD  Gross Import in USD
# count   121.000000                121.0                121.0
# mean   2015.000000    9975297520.661158    8775702479.338842
# std       3.175426   27017951202.748093   20218508673.014038
# min    2010.000000          136000000.0          510000000.0
# 25%    2012.000000          680000000.0         1620000000.0
# 50%    2015.000000         1230000000.0         3120000000.0
# 75%    2018.000000         3050000000.0         3690000000.0
# max    2020.000000       121000000000.0        98300000000.0

# %%
fig = px.line(df_1, x="Year", y=["Gross Export in USD", "Gross Import in USD"], color="Sector")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="84a52d10-ba84-4fc3-91b3-c6e01dbd7df3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("84a52d10-ba84-4fc3-91b3-c6e01dbd7df3")) {                    Plotly.newPlot(                        "84a52d10-ba84-4fc3-91b3-c6e01dbd7df3",                        [{"hovertemplate":"Sector=Textiles\u003cbr\u003evariable=Gross Export in USD\u003cbr\u003eYear=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Textiles","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Textiles","orientation":"h","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[693000000,818000000,707000000,680000000,691000000,643000000,643000000,608000000,656000000,784000000,817000000],"yaxis":"y","type":"scatter"},{"hovertemplate":"Sector=Textiles\u003cbr\u003evariable=Gross Import in USD\u003cbr\u003eYear=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Textiles","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Textiles","orientation":"h","showlegend":false,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[1430000000,1600000000,1390000000,1430000000,1510000000,1270000000,1330000000,1420000000,1510000000,1550000000,1430000000],"yaxis":"y","type":"scatter"},{"hovertemplate":"Sector=Other\u003cbr\u003evariable=Gross Export in USD\u003cbr\u003eYear=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Other","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Other","orientation":"h","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[573000000,677000000,856000000,785000000,909000000,731000000,892000000,820000000,915000000,394000000,393000000],"yaxis":"y","type":"scatter"},{"hovertemplate":"Sector=Other\u003cbr\u003evariable=Gross Import in USD\u003cbr\u003eYear=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Other","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Other","orientation":"h","showlegend":false,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[2240000000,2870000000,2700000000,2510000000,2590000000,1750000000,1510000000,1410000000,1620000000,1610000000,1130000000],"yaxis":"y","type":"scatter"},{"hovertemplate":"Sector=Metals\u003cbr\u003evariable=Gross Export in USD\u003cbr\u003eYear=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Metals","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Metals","orientation":"h","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[5140000000,5970000000,4710000000,4710000000,4950000000,4020000000,3800000000,4110000000,4730000000,4140000000,3610000000],"yaxis":"y","type":"scatter"},{"hovertemplate":"Sector=Metals\u003cbr\u003evariable=Gross Import in USD\u003cbr\u003eYear=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Metals","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Metals","orientation":"h","showlegend":false,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[3390000000,4040000000,3450000000,3490000000,3600000000,2440000000,2340000000,2790000000,3260000000,2750000000,2500000000],"yaxis":"y","type":"scatter"},{"hovertemplate":"Sector=Machinery\u003cbr\u003evariable=Gross Export in USD\u003cbr\u003eYear=%{x}\u003cbr\u003evalue=%{y}\u003cex ...

# %%
fig = px.bar(df_1.sort_values(["Gross Export in USD"]), x="Gross Export in USD", y="Year", color="Sector",orientation="h")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="2b52b2b9-f616-475b-9c6f-c1e94ecd2e15" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2b52b2b9-f616-475b-9c6f-c1e94ecd2e15")) {                    Plotly.newPlot(                        "2b52b2b9-f616-475b-9c6f-c1e94ecd2e15",                        [{"alignmentgroup":"True","hovertemplate":"Sector=Minerals\u003cbr\u003eGross Export in USD=%{x}\u003cbr\u003eYear=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Minerals","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Minerals","offsetgroup":"Minerals","orientation":"h","showlegend":true,"textposition":"auto","x":[136000000,158000000,178000000,181000000,249000000,291000000,331000000,354000000,363000000,369000000,414000000],"xaxis":"x","y":[2020,2016,2019,2017,2018,2015,2013,2010,2012,2011,2014],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sector=Other\u003cbr\u003eGross Export in USD=%{x}\u003cbr\u003eYear=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Other","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Other","offsetgroup":"Other","orientation":"h","showlegend":true,"textposition":"auto","x":[393000000,394000000,573000000,677000000,731000000,785000000,820000000,856000000,892000000,909000000,915000000],"xaxis":"x","y":[2020,2019,2010,2011,2015,2013,2017,2012,2016,2014,2018],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sector=Stone\u003cbr\u003eGross Export in USD=%{x}\u003cbr\u003eYear=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Stone","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Stone","offsetgroup":"Stone","orientation":"h","showlegend":true,"textposition":"auto","x":[411000000,420000000,489000000,527000000,541000000,546000000,548000000,628000000,724000000,730000000,952000000],"xaxis":"x","y":[2020,2010,2012,2019,2018,2015,2016,2013,2017,2011,2014],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sector=Electronics\u003cbr\u003eGross Export in USD=%{x}\u003cbr\u003eYear=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Electronics","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Electronics","offsetgroup":"Electronics","orientation":"h","showlegend":true,"textposition":"auto","x":[607000000,610000000,619000000,809000000,831000000,873000000,1060000000,1170000000,1530000000,1730000000,2500000000],"xaxis":"x","y":[2018,2017,2020,2016,2015,2019,2014,2010,2013,2012,2011],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sector=Textiles\u003cbr\u003eGross Export in USD=%{x}\u003cbr\u003eYear=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Textiles","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Textiles","offsetgroup":"Textiles","orientation":"h","showlegend":true,"textposition":"auto","x":[608000000,643000000,643000000,656000000,680000000,691000000,693000000,707000000,784000000,817000000,818000000],"xaxis":"x","y":[2017,2015,2016,2018,2013,2014,2010,2012,2019,2020,2011],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sector=Vehicles\u003cbr\u003eGross Export in USD=%{x}\u003cbr\u003eYear=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Vehicles","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Vehicles","offsetgroup":"Vehicles","orientation":"h","showlegend":true,"textposition":"auto","x":[869000000,886000000,935000000,952000000,985000000,1050000000,1070000000,1160000000,1230000000,1250000000,1450000000],"xaxis":"x","y":[2010,2013,2012,2016,2014,2015,2011,2017,2019,2018,2020],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sector=Agriculture\u003cbr\u003eGross Export in USD=%{x}\u003cbr\u003eYear=%{ ...

# %%
fig_2 = px.bar(df_1.sort_values(["Gross Import in USD"]),y="Year", x="Gross Import in USD", color="Sector", orientation="h")
fig_2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="508d1469-4643-48d8-84d8-14e2301a2855" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("508d1469-4643-48d8-84d8-14e2301a2855")) {                    Plotly.newPlot(                        "508d1469-4643-48d8-84d8-14e2301a2855",                        [{"alignmentgroup":"True","hovertemplate":"Sector=Stone\u003cbr\u003eGross Import in USD=%{x}\u003cbr\u003eYear=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Stone","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Stone","offsetgroup":"Stone","orientation":"h","showlegend":true,"textposition":"auto","x":[510000000,536000000,544000000,560000000,626000000,694000000,698000000,771000000,851000000,910000000,1060000000],"xaxis":"x","y":[2019,2018,2020,2015,2014,2017,2016,2010,2013,2012,2011],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sector=Other\u003cbr\u003eGross Import in USD=%{x}\u003cbr\u003eYear=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Other","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Other","offsetgroup":"Other","orientation":"h","showlegend":true,"textposition":"auto","x":[1130000000,1410000000,1510000000,1610000000,1620000000,1750000000,2240000000,2510000000,2590000000,2700000000,2870000000],"xaxis":"x","y":[2020,2017,2016,2019,2018,2015,2010,2013,2014,2012,2011],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sector=Textiles\u003cbr\u003eGross Import in USD=%{x}\u003cbr\u003eYear=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Textiles","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Textiles","offsetgroup":"Textiles","orientation":"h","showlegend":true,"textposition":"auto","x":[1270000000,1330000000,1390000000,1420000000,1430000000,1430000000,1430000000,1510000000,1510000000,1550000000,1600000000],"xaxis":"x","y":[2015,2016,2012,2017,2010,2020,2013,2014,2018,2019,2011],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sector=Electronics\u003cbr\u003eGross Import in USD=%{x}\u003cbr\u003eYear=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Electronics","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Electronics","offsetgroup":"Electronics","orientation":"h","showlegend":true,"textposition":"auto","x":[1370000000,1430000000,1560000000,1640000000,1720000000,2020000000,2140000000,2160000000,2180000000,2230000000,2340000000],"xaxis":"x","y":[2017,2020,2010,2018,2016,2015,2011,2019,2014,2013,2012],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sector=Minerals\u003cbr\u003eGross Import in USD=%{x}\u003cbr\u003eYear=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Minerals","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Minerals","offsetgroup":"Minerals","orientation":"h","showlegend":true,"textposition":"auto","x":[1530000000,1620000000,1790000000,1980000000,2470000000,2700000000,3080000000,3130000000,3730000000,3850000000,4080000000],"xaxis":"x","y":[2020,2016,2017,2015,2019,2018,2010,2014,2012,2013,2011],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sector=Metals\u003cbr\u003eGross Import in USD=%{x}\u003cbr\u003eYear=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Metals","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Metals","offsetgroup":"Metals","orientation":"h","showlegend":true,"textposition":"auto","x":[2340000000,2440000000,2500000000,2750000000,2790000000,3260000000,3390000000,3450000000,3490000000,3600000000,4040000000],"xaxis":"x","y":[2016,2015,2020,2019,2017,2018,2010,2012,2013,2014,2011],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Sector=Machinery\u003cbr\u003eGross Impo ...

# %% [markdown]
# #Exports and imports of Germany from 2010 to 2020

# %%
germany_ex = "https://www.dropbox.com/scl/fi/rr9us1t56k9gpon0zpcuy/What-did-Germany-export-between-2010-and-2020_.csv?rlkey=538pc7805vz7xcz0iwrxt1ly6&dl=1"
df_GE = (pd.read_csv(germany_ex)
        .drop('Code', axis=1)
        .rename(columns={'Current Gross Export': 'Gross Export in USD'})
        .assign(**{'Gross Export in USD': lambda x: x['Gross Export in USD'].str.replace("$", "")
        .str.replace('M', 'e6')
        .str.replace('B', 'e9')})
        .assign(**{'Gross Export in USD': lambda x: pd.to_numeric(x['Gross Export in USD'], errors='coerce').astype('Int64')})
        .sort_values(by="Year")
       )

germany_im = "https://www.dropbox.com/scl/fi/lzhrmgy292ow349llipyb/What-did-Germany-import-between-2010-and-2020_.csv?rlkey=w3m2k2qho257llrw4jon7wgp8&dl=1"
df_GI = (pd.read_csv(germany_im)
        .drop('Code', axis=1)
        .rename(columns={'Current Gross Import': 'Gross Import in USD'})
        .assign(**{'Gross Import in USD': lambda x: x['Gross Import in USD'].str.replace("$", "")
        .str.replace('M', 'e6')
        .str.replace('B', 'e9')})
        .assign(**{'Gross Import in USD': lambda x: pd.to_numeric(x['Gross Import in USD'], errors='coerce').astype('Int64')})
        .sort_values(by="Year")
       )

Gross_Import_Germany = df_GI['Gross Import in USD']
df_GE['Gross Import in USD'] = Gross_Import_Germany

df_GE
# Out:
# <ipython-input-18-39aed3f588d1>:5: FutureWarning:
#
# The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#
# <ipython-input-18-39aed3f588d1>:16: FutureWarning:
#
# The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#                                            Name  Year  Gross Export in USD  \
# 0    Textiles, garments, footwear and furniture  2010          52100000000
# 99                                        Other  2010          55600000000
# 44                                       Metals  2010         102000000000
# 77                    Machinery and instruments  2010         281000000000
# 22                    Stone, glass and ceramics  2010          29900000000
# ..                                          ...   ...                  ...
# 65                       Chemicals and plastics  2020         277000000000
# 87                    Machinery and instruments  2020         313000000000
# 32                    Stone, glass and ceramics  2020          35600000000
# 43              Minerals, fuels, ores and salts  2020          22100000000
# 120                                    Services  2020         319000000000
#
#         Sector  Gross Import in USD
# 0     Textiles          68400000000
# 99       Other          37300000000
# 44      Metals          88000000000
# 77   Machinery         157000000000
# 22       Stone          27000000000
# ..         ...                  ...
# 65   Chemicals         194000000000
# 87   Machinery         198000000000
# 32       Stone          37100000000
# 43    Minerals          58800000000
# 120   Services         316000000000
#
# [121 rows x 5 columns]

# %%
fig = px.line(df_GE, x="Year", y='Gross Export in USD', color="Sector")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="5713b002-db7b-48b4-b036-198f7d1de810" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5713b002-db7b-48b4-b036-198f7d1de810")) {                    Plotly.newPlot(                        "5713b002-db7b-48b4-b036-198f7d1de810",                        [{"hovertemplate":"Sector=Textiles\u003cbr\u003eYear=%{x}\u003cbr\u003eGross Export in USD=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Textiles","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Textiles","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[52100000000,61000000000,54700000000,56900000000,60100000000,52700000000,54400000000,60700000000,66900000000,62300000000,59700000000],"yaxis":"y","type":"scatter"},{"hovertemplate":"Sector=Other\u003cbr\u003eYear=%{x}\u003cbr\u003eGross Export in USD=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Other","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Other","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[55600000000,60200000000,57800000000,62000000000,68500000000,61400000000,61100000000,56600000000,63700000000,89000000000,69600000000],"yaxis":"y","type":"scatter"},{"hovertemplate":"Sector=Metals\u003cbr\u003eYear=%{x}\u003cbr\u003eGross Export in USD=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Metals","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Metals","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[102000000000,124000000000,112000000000,111000000000,113000000000,94900000000,91700000000,104000000000,113000000000,104000000000,94400000000],"yaxis":"y","type":"scatter"},{"hovertemplate":"Sector=Machinery\u003cbr\u003eYear=%{x}\u003cbr\u003eGross Export in USD=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Machinery","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Machinery","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[281000000000,331000000000,311000000000,318000000000,327000000000,287000000000,288000000000,325000000000,356000000000,339000000000,313000000000],"yaxis":"y","type":"scatter"},{"hovertemplate":"Sector=Stone\u003cbr\u003eYear=%{x}\u003cbr\u003eGross Export in USD=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Stone","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Stone","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[29900000000,38600000000,35300000000,32900000000,30500000000,26000000000,27500000000,28300000000,30200000000,31600000000,35600000000],"yaxis":"y","type":"scatter"},{"hovertemplate":"Sector=Services\u003cbr\u003eYear=%{x}\u003cbr\u003eGross Export in USD=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Services","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Services","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[231000000000,256000000000,256000000000,277000000000,303000000000,281000000000,293000000000,322000000000,357000000000,356000000000,319000000000],"yaxis":"y","type":"scatter"},{"hovertemplate":"Sector=Agriculture\u003cbr\u003eYear=%{x}\u003cbr\u003eGross Export in USD=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Agriculture","line":{ ...

# %%
fig = px.line(df_GE, x="Year", y='Gross Import in USD', color="Sector")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="84a55709-f321-431b-b74e-2a2f915019fe" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("84a55709-f321-431b-b74e-2a2f915019fe")) {                    Plotly.newPlot(                        "84a55709-f321-431b-b74e-2a2f915019fe",                        [{"hovertemplate":"Sector=Textiles\u003cbr\u003eYear=%{x}\u003cbr\u003eGross Import in USD=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Textiles","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Textiles","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[68400000000,83500000000,74500000000,80600000000,87400000000,77200000000,80100000000,84300000000,90900000000,91300000000,95000000000],"yaxis":"y","type":"scatter"},{"hovertemplate":"Sector=Other\u003cbr\u003eYear=%{x}\u003cbr\u003eGross Import in USD=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Other","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Other","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[37300000000,29700000000,39600000000,31500000000,30200000000,35600000000,39000000000,44500000000,49900000000,116000000000,88900000000],"yaxis":"y","type":"scatter"},{"hovertemplate":"Sector=Metals\u003cbr\u003eYear=%{x}\u003cbr\u003eGross Import in USD=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Metals","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Metals","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[88000000000,113000000000,95900000000,94400000000,98300000000,81700000000,79000000000,92200000000,103000000000,91100000000,81200000000],"yaxis":"y","type":"scatter"},{"hovertemplate":"Sector=Machinery\u003cbr\u003eYear=%{x}\u003cbr\u003eGross Import in USD=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Machinery","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Machinery","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[157000000000,187000000000,173000000000,177000000000,187000000000,166000000000,169000000000,185000000000,203000000000,206000000000,198000000000],"yaxis":"y","type":"scatter"},{"hovertemplate":"Sector=Stone\u003cbr\u003eYear=%{x}\u003cbr\u003eGross Import in USD=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Stone","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Stone","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[27000000000,34400000000,30900000000,29500000000,28400000000,25300000000,26600000000,28400000000,30300000000,30500000000,37100000000],"yaxis":"y","type":"scatter"},{"hovertemplate":"Sector=Services\u003cbr\u003eYear=%{x}\u003cbr\u003eGross Import in USD=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Services","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Services","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[264000000000,298000000000,295000000000,329000000000,337000000000,301000000000,317000000000,349000000000,375000000000,376000000000,316000000000],"yaxis":"y","type":"scatter"},{"hovertemplate":"Sector=Agriculture\u003cbr\u003eYear=%{x}\u003cbr\u003eGross Import in USD=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Agriculture","line":{"colo ...

# %%
fig_GE = px.treemap(df_GE,
                   path=["Year", "Sector"],
                   values="Gross Export in USD",
                   color="Sector")
fig_GE.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="44920006-9b0a-486d-993d-09c7678b0dbd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("44920006-9b0a-486d-993d-09c7678b0dbd")) {                    Plotly.newPlot(                        "44920006-9b0a-486d-993d-09c7678b0dbd",                        [{"branchvalues":"total","customdata":[["Services"],["Textiles"],["Electronics"],["Vehicles"],["Machinery"],["Metals"],["Chemicals"],["Stone"],["Minerals"],["Other"],["Agriculture"],["Metals"],["Chemicals"],["Machinery"],["Other"],["Electronics"],["Services"],["Stone"],["Minerals"],["Textiles"],["Agriculture"],["Vehicles"],["Metals"],["Minerals"],["Services"],["Vehicles"],["Stone"],["Machinery"],["Other"],["Agriculture"],["Chemicals"],["Textiles"],["Electronics"],["Textiles"],["Stone"],["Metals"],["Minerals"],["Electronics"],["Services"],["Machinery"],["Chemicals"],["Agriculture"],["Other"],["Vehicles"],["Other"],["Services"],["Agriculture"],["Minerals"],["Metals"],["Stone"],["Electronics"],["Chemicals"],["Textiles"],["Vehicles"],["Machinery"],["Textiles"],["Stone"],["Machinery"],["Metals"],["Vehicles"],["Minerals"],["Agriculture"],["Electronics"],["Chemicals"],["Services"],["Other"],["Agriculture"],["Metals"],["Electronics"],["Other"],["Minerals"],["Chemicals"],["Machinery"],["Services"],["Textiles"],["Stone"],["Vehicles"],["Textiles"],["Services"],["Stone"],["Vehicles"],["Machinery"],["Other"],["Electronics"],["Agriculture"],["Metals"],["Chemicals"],["Minerals"],["Textiles"],["Machinery"],["Chemicals"],["Stone"],["Metals"],["Minerals"],["Other"],["Services"],["Agriculture"],["Vehicles"],["Electronics"],["Electronics"],["Chemicals"],["Vehicles"],["Agriculture"],["Machinery"],["Other"],["Metals"],["Services"],["Minerals"],["Textiles"],["Stone"],["Machinery"],["Services"],["Agriculture"],["Chemicals"],["Metals"],["Vehicles"],["Stone"],["Electronics"],["Textiles"],["Minerals"],["Other"],["(?)"],["(?)"],["(?)"],["(?)"],["(?)"],["(?)"],["(?)"],["(?)"],["(?)"],["(?)"],["(?)"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}\u003cbr\u003eGross Export in USD=%{value}\u003cbr\u003eparent=%{parent}\u003cbr\u003eid=%{id}\u003cbr\u003eSector=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["2012\u002fServices","2019\u002fTextiles","2015\u002fElectronics","2013\u002fVehicles","2017\u002fMachinery","2013\u002fMetals","2016\u002fChemicals","2010\u002fStone","2019\u002fMinerals","2014\u002fOther","2016\u002fAgriculture","2020\u002fMetals","2017\u002fChemicals","2015\u002fMachinery","2010\u002fOther","2017\u002fElectronics","2010\u002fServices","2016\u002fStone","2015\u002fMinerals","2011\u002fTextiles","2017\u002fAgriculture","2016\u002fVehicles","2018\u002fMetals","2011\u002fMinerals","2011\u002fServices","2014\u002fVehicles","2011\u002fStone","2013\u002fMachinery","2011\u002fOther","2019\u002fAgriculture","2019\u002fChemicals","2020\u002fTextiles","2010\u002fElectronics","2018\u002fTextiles","2019\u002fStone","2019\u002fMetals","2013\u002fMinerals","2011\u002fElectronics","2013\u002fServices","2012\u002fMachinery","2015\u002fChemicals","2013\u002fAgriculture","2012\u002fOther","2017\u002fVehicles","2018\u002fOther","2017\u002fServices","2012\u002fAgriculture","2020\u002fMinerals","2015\u002fMetals","2017\u002fStone","2012\u002fElectronics","2013\u002fChemicals","2012\u002fTextiles","2015\u002fVehicles","2010\u002fMachinery","2017\u002fTextiles","2020\u002fStone","2020\u002fMachinery","2010\u002fMetals","2019\u002fVehicles","2017\u002fMinerals","2018\u002fAgriculture","2020\u002fElectronics","2014\u002fChemicals","2019\u002fServices","2013\u002fOther","2011\u002fAgriculture","2016\u002fMetals","2013\u002fElectronics","2015\u002fOther","2010\u002fMin ...

# %% [markdown]
# #Exports and imports of Belgium from 2010 to 2020

# %%
belgium_ex = "https://www.dropbox.com/scl/fi/awy9lm0fyku4wp6uva9x8/What-did-Belgium-export-between-2010-and-2020_.csv?rlkey=oq2tvqetjs962fhtxj8erfk6f&dl=1"
df_BE = (pd.read_csv(belgium_ex)
        .drop('Code', axis=1)
        .rename(columns={'Current Gross Export': 'Gross Export in USD'})
        .assign(**{'Gross Export in USD': lambda x: x['Gross Export in USD'].str.replace("$", "")
        .str.replace('M', 'e6')
        .str.replace('B', 'e9')})
        .assign(**{'Gross Export in USD': lambda x: pd.to_numeric(x['Gross Export in USD'], errors='coerce').astype('Int64')})
        .sort_values(by="Year")
       )

belgium_im = "https://www.dropbox.com/scl/fi/b80a2sq5khlrnymheuab0/What-did-Belgium-import-between-2010-and-2020_.csv?rlkey=h83q5irax243zh7i8307kn3nv&dl=1"
df_BI = (pd.read_csv(belgium_im)
        .drop('Code', axis=1)
        .rename(columns={'Current Gross Import': 'Gross Import in USD'})
        .assign(**{'Gross Import in USD': lambda x: x['Gross Import in USD'].str.replace("$", "")
        .str.replace('M', 'e6')
        .str.replace('B', 'e9')})
        .assign(**{'Gross Import in USD': lambda x: pd.to_numeric(x['Gross Import in USD'], errors='coerce').astype('Int64')})
        .sort_values(by="Year")
       )

Gross_Import_Belgium = df_BI['Gross Import in USD']
df_BE['Gross Import in USD'] = Gross_Import_Belgium

df_BE
# Out:
# <ipython-input-22-a71973bfff81>:5: FutureWarning:
#
# The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#
# <ipython-input-22-a71973bfff81>:16: FutureWarning:
#
# The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#                                            Name  Year  Gross Export in USD  \
# 0    Textiles, garments, footwear and furniture  2010          17000000000
# 99                                        Other  2010           7940000000
# 44                                       Metals  2010          31400000000
# 77                    Machinery and instruments  2010          34600000000
# 22                    Stone, glass and ceramics  2010          24700000000
# ..                                          ...   ...                  ...
# 65                       Chemicals and plastics  2020         107000000000
# 87                    Machinery and instruments  2020          31000000000
# 32                    Stone, glass and ceramics  2020          20000000000
# 43              Minerals, fuels, ores and salts  2020          19100000000
# 120                                    Services  2020         121000000000
#
#         Sector  Gross Import in USD
# 0     Textiles          18900000000
# 99       Other           9030000000
# 44      Metals          27900000000
# 77   Machinery          39800000000
# 22       Stone          22000000000
# ..         ...                  ...
# 65   Chemicals          94900000000
# 87   Machinery          42100000000
# 32       Stone          16400000000
# 43    Minerals          26900000000
# 120   Services         119000000000
#
# [121 rows x 5 columns]

# %%
fig = px.line(df_BE, x="Year", y='Gross Export in USD', color="Sector")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="0c2f272c-8c18-4b69-bbf1-6bd2c78147f4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0c2f272c-8c18-4b69-bbf1-6bd2c78147f4")) {                    Plotly.newPlot(                        "0c2f272c-8c18-4b69-bbf1-6bd2c78147f4",                        [{"hovertemplate":"Sector=Textiles\u003cbr\u003eYear=%{x}\u003cbr\u003eGross Export in USD=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Textiles","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Textiles","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[17000000000,19600000000,17000000000,17600000000,19600000000,10800000000,10500000000,10300000000,10300000000,11100000000,11700000000],"yaxis":"y","type":"scatter"},{"hovertemplate":"Sector=Other\u003cbr\u003eYear=%{x}\u003cbr\u003eGross Export in USD=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Other","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Other","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[7940000000,9000000000,8540000000,10200000000,11500000000,8490000000,8660000000,9530000000,3870000000,3800000000,3730000000],"yaxis":"y","type":"scatter"},{"hovertemplate":"Sector=Metals\u003cbr\u003eYear=%{x}\u003cbr\u003eGross Export in USD=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Metals","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Metals","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[31400000000,38500000000,32100000000,32100000000,31900000000,21500000000,20900000000,25900000000,29000000000,26200000000,23400000000],"yaxis":"y","type":"scatter"},{"hovertemplate":"Sector=Machinery\u003cbr\u003eYear=%{x}\u003cbr\u003eGross Export in USD=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Machinery","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Machinery","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[34600000000,42900000000,39200000000,40400000000,42500000000,28600000000,29700000000,31500000000,33100000000,32200000000,31000000000],"yaxis":"y","type":"scatter"},{"hovertemplate":"Sector=Stone\u003cbr\u003eYear=%{x}\u003cbr\u003eGross Export in USD=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Stone","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Stone","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[24700000000,32700000000,30000000000,30600000000,30800000000,22600000000,23700000000,22700000000,22700000000,22900000000,20000000000],"yaxis":"y","type":"scatter"},{"hovertemplate":"Sector=Services\u003cbr\u003eYear=%{x}\u003cbr\u003eGross Export in USD=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Services","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Services","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[97900000000,105000000000,106000000000,114000000000,125000000000,109000000000,109000000000,118000000000,124000000000,124000000000,121000000000],"yaxis":"y","type":"scatter"},{"hovertemplate":"Sector=Agriculture\u003cbr\u003eYear=%{x}\u003cbr\u003eGross Export in USD=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Agriculture","line":{"color":"#FF6692","dash":"sol ...

# %%
fig = px.line(df_BE, x="Year", y='Gross Import in USD', color="Sector")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="9cbc4f99-7bd7-4d69-a7b1-b77d08b68113" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9cbc4f99-7bd7-4d69-a7b1-b77d08b68113")) {                    Plotly.newPlot(                        "9cbc4f99-7bd7-4d69-a7b1-b77d08b68113",                        [{"hovertemplate":"Sector=Textiles\u003cbr\u003eYear=%{x}\u003cbr\u003eGross Import in USD=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Textiles","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Textiles","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[18900000000,21500000000,19700000000,21500000000,22700000000,19800000000,19400000000,20100000000,20600000000,19100000000,18700000000],"yaxis":"y","type":"scatter"},{"hovertemplate":"Sector=Other\u003cbr\u003eYear=%{x}\u003cbr\u003eGross Import in USD=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Other","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Other","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[9030000000,8300000000,8740000000,7910000000,8320000000,9020000000,9280000000,9590000000,11200000000,7860000000,7010000000],"yaxis":"y","type":"scatter"},{"hovertemplate":"Sector=Metals\u003cbr\u003eYear=%{x}\u003cbr\u003eGross Import in USD=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Metals","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Metals","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[27900000000,34000000000,29200000000,28100000000,28100000000,22800000000,21900000000,25700000000,29100000000,24600000000,22300000000],"yaxis":"y","type":"scatter"},{"hovertemplate":"Sector=Machinery\u003cbr\u003eYear=%{x}\u003cbr\u003eGross Import in USD=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Machinery","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Machinery","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[39800000000,48000000000,44600000000,46000000000,48500000000,41700000000,42500000000,45300000000,46900000000,44800000000,42100000000],"yaxis":"y","type":"scatter"},{"hovertemplate":"Sector=Stone\u003cbr\u003eYear=%{x}\u003cbr\u003eGross Import in USD=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Stone","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Stone","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[22000000000,31000000000,28600000000,29000000000,28300000000,24800000000,24900000000,24400000000,24700000000,20400000000,16400000000],"yaxis":"y","type":"scatter"},{"hovertemplate":"Sector=Services\u003cbr\u003eYear=%{x}\u003cbr\u003eGross Import in USD=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Services","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Services","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[88000000000,96900000000,99300000000,105000000000,118000000000,104000000000,105000000000,115000000000,124000000000,124000000000,119000000000],"yaxis":"y","type":"scatter"},{"hovertemplate":"Sector=Agriculture\u003cbr\u003eYear=%{x}\u003cbr\u003eGross Import in USD=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Agriculture","line":{"color":"#FF6692","dash":"solid" ...

# %% [markdown]
# #Exports and imports of France from 2010 to 2020

# %%
france_ex = "https://www.dropbox.com/scl/fi/1nuqy9zopphf9ux47gte5/What-did-France-export-between-2010-and-2020_.csv?rlkey=eh80wedkkmt7my91mqdb44eic&dl=1"
df_FE = (pd.read_csv(france_ex)
        .drop('Code', axis=1)
        .rename(columns={'Current Gross Export': 'Gross Export in USD'})
        .assign(**{'Gross Export in USD': lambda x: x['Gross Export in USD'].str.replace("$", "")
        .str.replace('M', 'e6')
        .str.replace('B', 'e9')})
        .assign(**{'Gross Export in USD': lambda x: pd.to_numeric(x['Gross Export in USD'], errors='coerce').astype('Int64')})
        .sort_values(by="Year")
       )

france_im = "https://www.dropbox.com/scl/fi/d398r1kov1zwcub5h901i/What-did-France-import-between-2010-and-2020_.csv?rlkey=gq1vrs28ucod3lv4sg9f6letc&dl=1"
df_FI = (pd.read_csv(france_im)
        .drop('Code', axis=1)
        .rename(columns={'Current Gross Import': 'Gross Import in USD'})
        .assign(**{'Gross Import in USD': lambda x: x['Gross Import in USD'].str.replace("$", "")
        .str.replace('M', 'e6')
        .str.replace('B', 'e9')})
        .assign(**{'Gross Import in USD': lambda x: pd.to_numeric(x['Gross Import in USD'], errors='coerce').astype('Int64')})
        .sort_values(by="Year")
       )

Gross_Import_France = df_FI['Gross Import in USD']
df_FE['Gross Import in USD'] = Gross_Import_France

df_FE
# Out:
# <ipython-input-25-f99271f71bfb>:5: FutureWarning:
#
# The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#
# <ipython-input-25-f99271f71bfb>:16: FutureWarning:
#
# The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#                                            Name  Year  Gross Export in USD  \
# 0    Textiles, garments, footwear and furniture  2010          22000000000
# 99                                        Other  2010          12300000000
# 44                                       Metals  2010          39100000000
# 77                    Machinery and instruments  2010          79500000000
# 22                    Stone, glass and ceramics  2010           9880000000
# ..                                          ...   ...                  ...
# 65                       Chemicals and plastics  2020         115000000000
# 87                    Machinery and instruments  2020          73000000000
# 32                    Stone, glass and ceramics  2020          13800000000
# 43              Minerals, fuels, ores and salts  2020          11100000000
# 120                                    Services  2020         246000000000
#
#         Sector  Gross Import in USD
# 0     Textiles          46200000000
# 99       Other          18600000000
# 44      Metals          43400000000
# 77   Machinery          90000000000
# 22       Stone          13200000000
# ..         ...                  ...
# 65   Chemicals          96500000000
# 87   Machinery          95300000000
# 32       Stone          17200000000
# 43    Minerals          37300000000
# 120   Services         225000000000
#
# [121 rows x 5 columns]

# %%
fig = px.line(df_FE, x="Year", y='Gross Export in USD', color="Sector")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="7117b6ae-1206-40f8-84a0-ff81dfd3a46d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7117b6ae-1206-40f8-84a0-ff81dfd3a46d")) {                    Plotly.newPlot(                        "7117b6ae-1206-40f8-84a0-ff81dfd3a46d",                        [{"hovertemplate":"Sector=Textiles\u003cbr\u003eYear=%{x}\u003cbr\u003eGross Export in USD=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Textiles","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Textiles","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[22000000000,25000000000,23400000000,25000000000,25300000000,23200000000,23800000000,24700000000,27200000000,26500000000,22400000000],"yaxis":"y","type":"scatter"},{"hovertemplate":"Sector=Other\u003cbr\u003eYear=%{x}\u003cbr\u003eGross Export in USD=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Other","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Other","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[12300000000,14500000000,13900000000,14000000000,13500000000,12300000000,12300000000,12400000000,13400000000,13700000000,16700000000],"yaxis":"y","type":"scatter"},{"hovertemplate":"Sector=Metals\u003cbr\u003eYear=%{x}\u003cbr\u003eGross Export in USD=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Metals","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Metals","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[39100000000,45300000000,39800000000,38900000000,39700000000,32800000000,30000000000,35300000000,38300000000,34700000000,28900000000],"yaxis":"y","type":"scatter"},{"hovertemplate":"Sector=Machinery\u003cbr\u003eYear=%{x}\u003cbr\u003eGross Export in USD=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Machinery","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Machinery","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[79500000000,89000000000,85300000000,87800000000,88900000000,76700000000,76500000000,81800000000,89500000000,89700000000,73000000000],"yaxis":"y","type":"scatter"},{"hovertemplate":"Sector=Stone\u003cbr\u003eYear=%{x}\u003cbr\u003eGross Export in USD=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Stone","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Stone","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[9880000000,13000000000,13100000000,12700000000,13100000000,12400000000,12700000000,13500000000,14400000000,17300000000,13800000000],"yaxis":"y","type":"scatter"},{"hovertemplate":"Sector=Services\u003cbr\u003eYear=%{x}\u003cbr\u003eGross Export in USD=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Services","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Services","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[202000000000,237000000000,234000000000,254000000000,273000000000,256000000000,259000000000,275000000000,302000000000,296000000000,246000000000],"yaxis":"y","type":"scatter"},{"hovertemplate":"Sector=Agriculture\u003cbr\u003eYear=%{x}\u003cbr\u003eGross Export in USD=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Agriculture","line":{"color":"#FF6692","d ...

# %%
fig = px.line(df_FE, x="Year", y='Gross Import in USD', color="Sector")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="bc84d0f9-04d8-4f8f-8d30-4a2058f4a664" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bc84d0f9-04d8-4f8f-8d30-4a2058f4a664")) {                    Plotly.newPlot(                        "bc84d0f9-04d8-4f8f-8d30-4a2058f4a664",                        [{"hovertemplate":"Sector=Textiles\u003cbr\u003eYear=%{x}\u003cbr\u003eGross Import in USD=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Textiles","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Textiles","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[46200000000,53400000000,48600000000,51400000000,55400000000,47000000000,48800000000,50900000000,56500000000,54300000000,52600000000],"yaxis":"y","type":"scatter"},{"hovertemplate":"Sector=Other\u003cbr\u003eYear=%{x}\u003cbr\u003eGross Import in USD=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Other","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Other","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[18600000000,16800000000,20600000000,20200000000,18200000000,19100000000,21500000000,21600000000,25700000000,25200000000,30500000000],"yaxis":"y","type":"scatter"},{"hovertemplate":"Sector=Metals\u003cbr\u003eYear=%{x}\u003cbr\u003eGross Import in USD=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Metals","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Metals","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[43400000000,53400000000,45500000000,45200000000,45400000000,37900000000,37100000000,42100000000,46800000000,43600000000,37300000000],"yaxis":"y","type":"scatter"},{"hovertemplate":"Sector=Machinery\u003cbr\u003eYear=%{x}\u003cbr\u003eGross Import in USD=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Machinery","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Machinery","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[90000000000,104000000000,92100000000,95800000000,96800000000,84900000000,86900000000,97500000000,103000000000,107000000000,95300000000],"yaxis":"y","type":"scatter"},{"hovertemplate":"Sector=Stone\u003cbr\u003eYear=%{x}\u003cbr\u003eGross Import in USD=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Stone","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Stone","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[13200000000,15600000000,19700000000,18600000000,18600000000,16600000000,19200000000,18000000000,21100000000,19800000000,17200000000],"yaxis":"y","type":"scatter"},{"hovertemplate":"Sector=Services\u003cbr\u003eYear=%{x}\u003cbr\u003eGross Import in USD=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Services","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Services","orientation":"v","showlegend":true,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[182000000000,203000000000,203000000000,228000000000,253000000000,233000000000,237000000000,247000000000,274000000000,267000000000,225000000000],"yaxis":"y","type":"scatter"},{"hovertemplate":"Sector=Agriculture\u003cbr\u003eYear=%{x}\u003cbr\u003eGross Import in USD=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Agriculture","line":{"color":"#FF6692 ...

# %% [markdown]
# #Exports and imports of Netherlands from 2010 to 2020

# %%
netherlands_ex ='https://www.dropbox.com/scl/fi/xucwu4nufbt9n7hsg3v5g/What-did-Netherlands-export-between-2010-and-2020_.csv?rlkey=1j2xlopy3a52vznca87gwldxl&dl=1'

df_NE = (pd.read_csv(netherlands_ex)
        .drop('Code', axis=1)
        .rename(columns={'Current Gross Export': 'Gross Export in USD'})
        .assign(**{'Gross Export in USD': lambda x: x['Gross Export in USD'].str.replace("$", "")
        .str.replace('M', 'e6')
        .str.replace('B', 'e9')})
        .assign(**{'Gross Export in USD': lambda x: pd.to_numeric(x['Gross Export in USD'], errors='coerce').astype('Int64')})
        .sort_values(by="Year")
       )

netherlands_im = "https://www.dropbox.com/scl/fi/tagwodgvgb1vhpkgfxke9/What-did-Netherlands-import-between-2010-and-2020_.csv?rlkey=i6hw12orixqz5j80yzjle5x5d&dl=1"
df_NI = (pd.read_csv(netherlands_im)
        .drop('Code', axis=1)
        .rename(columns={'Current Gross Import': 'Gross Import in USD'})
        .assign(**{'Gross Import in USD': lambda x: x['Gross Import in USD'].str.replace("$", "")
        .str.replace('M', 'e6')
        .str.replace('B', 'e9')})
        .assign(**{'Gross Import in USD': lambda x: pd.to_numeric(x['Gross Import in USD'], errors='coerce').astype('Int64')})
        .sort_values(by="Year")
       )

Gross_Import_Netherlands = df_NI['Gross Import in USD']
df_NE['Gross Import in USD'] = Gross_Import_Netherlands

df_NE
# Out:
# <ipython-input-28-8efac2c46442>:6: FutureWarning:
#
# The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#
# <ipython-input-28-8efac2c46442>:17: FutureWarning:
#
# The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#                                            Name  Year  Gross Export in USD  \
# 0    Textiles, garments, footwear and furniture  2010          14900000000
# 99                                        Other  2010          44300000000
# 44                                       Metals  2010          30500000000
# 77                    Machinery and instruments  2010          83700000000
# 22                    Stone, glass and ceramics  2010           4570000000
# ..                                          ...   ...                  ...
# 65                       Chemicals and plastics  2020         105000000000
# 87                    Machinery and instruments  2020         106000000000
# 32                    Stone, glass and ceramics  2020           4300000000
# 43              Minerals, fuels, ores and salts  2020          42500000000
# 120                                    Services  2020         187000000000
#
#         Sector  Gross Import in USD
# 0     Textiles          24000000000
# 99       Other          28100000000
# 44      Metals          37100000000
# 77   Machinery          88500000000
# 22       Stone           7040000000
# ..         ...                  ...
# 65   Chemicals          83800000000
# 87   Machinery         101000000000
# 32       Stone           6100000000
# 43    Minerals          61000000000
# 120   Services         166000000000
#
# [121 rows x 5 columns]

# %%
#Add tree map all the countries for 2020
